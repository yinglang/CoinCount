# %% [markdown]
# ## 0. before work
#
# ```
# you must run ../data_prepare/data_prepare.ipynb to create rec dataset firstly
# and then run this train file
# ```

# %% [markdown]
# ## 1. import package and set global var

# %%
import mxnet as mx
from mxnet import gluon, image, autograd, nd
from mxnet.gluon import nn
from mxnet.contrib.ndarray import MultiBoxPrior, MultiBoxTarget, MultiBoxDetection
from mxnet import metric
from mxnet.gluon import model_zoo

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 120
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import time

import sys
sys.path.append("../")
from utils.utils import show_9_images, show_images, mkdir_if_not_exist, evaluate_MAP, draw_ROC

# dataset root dir
coins_root = "../dataset/"
sdl_root = coins_root + "sdl-coins/"
swiss_root = coins_root + "swiss-coins/"

data_shape = (3, 512, 512)
batch_size = 4
#mean = np.array([ 167.02477919,  157.20263027,  140.25492473])
#std = np.array([ 46.06696734,  47.12624331,  50.81295717])
rgb_mean = np.array([123, 117, 104])
std = np.array([58.395, 57.12, 57.375])

ctx = mx.gpu(0)
resize = (data_shape[1], data_shape[2])

# %% [markdown]
# ## 2. load data and plot data
# ```
# ImageDetIter will call CreateDetAugmenter
# if mean==True, it will sub defualt mean
# if std==True, it will div default std
#
# both mean and std can not set to False.
#
# or you can cal them and set them as np.array([r, g, b])
# ```

# %%
?? image.CreateDetAugmenter

# %%
def get_iterators(rec_prefix, data_shape, batch_size):
    class_names = ['1yuan', '0.5yuan']
    num_class = len(class_names)
    train_iter = image.ImageDetIter(
        batch_size=batch_size, 
        data_shape=data_shape,
        path_imgrec=rec_prefix + '_train.rec',
        path_imgidx=rec_prefix + '_train.idx',
        shuffle=True,
        mean=True,
        std=True,
        rand_crop=1,
        min_object_covered=0.95,
        max_attempts=200,
        brightness=0.2,
        contrast=0.2,
        saturation=0.2,
        hue=0.1,
        rand_mirror=True,
        aspect_ratio_range=(0.5, 2),
        pca_noise=0.01,
        #rand_gray=True
    )
    
    valid_iter = image.ImageDetIter(
        batch_size=batch_size, 
        data_shape=data_shape,
        path_imgrec=rec_prefix+'_val.rec',
        shuffle=False,
        mean=True,
        std=True
    )
    
    return train_iter, valid_iter, class_names, num_class

rec_prefix = sdl_root+"rec/sdl_" + str(resize[0]) + "_" + str(resize[1])
train_data, valid_data, class_names, num_class = get_iterators(rec_prefix, data_shape, batch_size)

# %%
"""
data plot
"""
mpl.rcParams['figure.dpi'] = 120

train_data.reset()
batch = train_data.next()
images = batch.data[0][:4]
labels = batch.label[0][:4]

show_images(images.asnumpy(), labels.asnumpy(), rgb_mean, std, show_text=True, fontsize=6, MN=(2, 4))
#show_9_images(images.asnumpy(), labels, rgb_mean)
print labels.shape
# Out:
# (4L, 14L, 5L)

# %% [markdown]
# ## 3.

# %%
"""
model define
"""

def get_alexnet_conv(ctx):
    alexnet = model_zoo.vision.alexnet(pretrained=True, ctx=ctx)
    net = gluon.nn.HybridSequential()
    net.add(*(alexnet.features[:8]))
    return net

def get_vgg11bn_conv(ctx):
    vgg11bnnet = model_zoo.vision.vgg11_bn(pretrained=True, ctx=ctx)
    net = gluon.nn.HybridSequential()
    net.add(*(vgg11bnnet.features[:28]))
    return net

def get_mobilenet_1_conv(ctx):
    mobilenet = model_zoo.vision.mobilenet1_0()
    net = gluon.nn.HybridSequential()
    net.add(*mobilenet.features[:33])
    net.initialize(ctx=ctx)
    return net

def down_sample(num_filter):
    out = nn.HybridSequential()
    for _ in range(2):
        out.add(nn.Conv2D(num_filter, kernel_size=3, strides=1, padding=1))
        out.add(nn.BatchNorm(in_channels=num_filter))
        out.add(nn.Activation('relu'))
    out.add(nn.MaxPool2D(2))
    return out

def class_predictor(num_class, num_anchors):
    return nn.Conv2D(num_anchors * (num_class + 1), kernel_size=3, strides=1, padding=1)

def box_predictor(num_anchors):
    return nn.Conv2D(num_anchors * 4, kernel_size=3, strides=1, padding=1)

class SSD(nn.HybridBlock):
    def __init__(self, num_class, sizes_list, ratios_list, ctx, verbose=False, **kwargs):
        super(SSD, self).__init__(**kwargs)
        self.num_class = num_class
        self.sizes_list = sizes_list
        self.ratios_list = ratios_list
        self.num_anchors = num_anchors = (len(sizes_list[0]) + len(ratios_list[0]) - 1)
        self.verbose = verbose
        
        with self.name_scope():
            # part 1
#             self.body = nn.HybridSequential()
#             for filters in [16, 32, 64]:
#                 self.body.add(down_sample(filters))
            # self.body = get_vgg11bn_conv(ctx)
            self.body = get_vgg11bn_conv(ctx)

            # part 2
            self.downsamples = nn.HybridSequential()
            for _ in range(3):
                self.downsamples.add(down_sample(128))

            # part 3
            self.class_predictors = nn.HybridSequential()
            self.box_predictors = nn.HybridSequential()
            for _ in range(5):
                self.class_predictors.add(class_predictor(num_class, num_anchors))
                self.box_predictors.add(box_predictor(num_anchors))
                
            self.downsamples.initialize(ctx=ctx)
            self.class_predictors.initialize(ctx=ctx)
            self.box_predictors.initialize(ctx=ctx)
            
    def hybrid_forward(self, F, x):
        x = self.body(x)
        cls_preds = []
        box_preds = []
        anchors = []
        for i in range(5):
            cls_preds.append((self.class_predictors[i](x)).transpose((0, 2, 3, 1)).flatten())
            box_preds.append((self.box_predictors[i](x)).transpose((0, 2, 3, 1)).flatten())
            anchors.append(MultiBoxPrior(x, sizes=self.sizes_list[i], ratios=self.ratios_list[i]))

            if self.verbose:
                print "predict scale", i, x.shape, 'with', anchors[-1].shape, 'anchors'

            if i < 3:
                x = self.downsamples[i](x)
            elif i == 3:
                x = F.Pooling(x, global_pool=True, pool_type='max', kernel=(x.shape[2], x.shape[3]))
        cls_preds = nd.concat(*cls_preds, dim=1).reshape((0, -1, num_class+1))
        box_preds = nd.concat(*box_preds, dim=1)
        anchors = nd.concat(*anchors, dim=1)
        return anchors, box_preds, cls_preds

sizes_list = [[.2,.272], [.37,.447], [.54,.619],
                      [.71,.79], [.88,.961]]
ratios_list = [[1, 2, .5]]*5

# %%
import time
net = SSD(2, sizes_list, ratios_list, ctx=mx.cpu(), verbose=True, prefix="ssd_")
print net
#net.initialize()
tic = time.time()
anchors, box_preds, cls_preds = net(batch.data[0])
print time.time() - tic
box_offset, box_mask, cls_labels = MultiBoxTarget(anchors, batch.label[0], cls_preds.transpose(axes=(0, 2, 1)))
print cls_labels.shape, cls_preds.shape, box_offset.shape, box_mask.shape
# Out:
# SSD(
#   (downsamples): HybridSequential(
#     (0): HybridSequential(
#       (0): Conv2D(128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1, in_channels=128)
#       (2): Activation(relu)
#       (3): Conv2D(128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1, in_channels=128)
#       (5): Activation(relu)
#       (6): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     )
#     (1): HybridSequential(
#       (0): Conv2D(128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1, in_channels=128)
#       (2): Activation(relu)
#       (3): Conv2D(128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1, in_channels=128)
#       (5): Activation(relu)
#       (6): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     )
#     (2): HybridSequential(
#       (0): Conv2D(128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1, in_channels=128)
#       (2): Activation(relu)
#       (3): Conv2D(128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1, in_channels=128)
#       (5): Activation(relu)
#       (6): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     )
#   )
#   (box_predictors): HybridSequential(
#     (0): Conv2D(16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2D(16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2D(16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Conv2D(16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Conv2D(16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (body): HybridSequential(
#     (0): Conv2D(64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1)
#     (2): Activation(relu)
#     (3): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     (4): Conv2D(128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1)
#     (6): Activation(relu)
#     (7): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     (8): Conv2D(256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1)
#     (10): Activation(relu)
#     (11): Conv2D(256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1)
#     (13): Activation(relu)
#     (14): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     (15): Conv2D(512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1)
#     (17): Activation(relu)
#     (18): Conv2D(512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1)
#     (20): Activation(relu)
#     (21): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     (22): Conv2D(512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1)
#     (24): Activation(relu)
#     (25): Conv2D(512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): BatchNorm(fix_gamma=False, eps=1e-05, momentum=0.9, axis=1)
#     (27): Activation(relu)
#   )
#   (class_predictors): HybridSequential(
#     (0): Conv2D(12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2D(12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2D(12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Conv2D(12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Conv2D(12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# predict scale 0 (4L, 512L, 32L, 32L) with (1L, 4096L, 4L) anchors
# predict scale 1 (4L, 128L, 16L, 16L) with (1L, 1024L, 4L) anchors
# predict scale 2 (4L, 128L, 8L, 8L) with (1L, 256L, 4L) anchors
# predict scale 3 (4L, 128L, 4L, 4L) with (1L, 64L, 4L) anchors
# predict scale 4 (4L, 128L, 1L, 1L) with (1L, 4L, 4L) anchors
# 0.018737077713
# (4L, 5444L) (4L, 5444L, 3L) (4L, 21776L) (4L, 21776L)

# %%
"""
loss define
"""
class FocalLoss(gluon.loss.Loss):
    def __init__(self, axis=-1, alpha=0.25, gama=2, batch_axis=0, **kwargs):
        super(FocalLoss, self).__init__(None, batch_axis, **kwargs)
        self.alpha = alpha
        self.gama = gama
        self.axis = axis
        self.batch_axis = batch_axis
        
    def hybrid_forward(self, F, y, label):
        y = F.softmax(y)
        py = y.pick(label, axis=self.axis, keepdims=True)
        loss = - (self.alpha * ((1 - py) ** self.gama)) * py.log()
        return loss.mean(axis=self.batch_axis, exclude=True)
    
class SmoothL1Loss(gluon.loss.Loss):
    def __init__(self, batch_axis=0, **kwargs):
        super(SmoothL1Loss, self).__init__(None, batch_axis, **kwargs)
        self.batch_axis = batch_axis
        
    def hybrid_forward(self, F, y, label, mask):
        loss = F.smooth_l1((y - label) * mask, scalar=1.0)
        return loss.mean(axis=self.batch_axis, exclude=True)
    
cls_loss = FocalLoss()
#cls_loss = gluon.loss.SoftmaxCrossEntropyLoss()
box_loss = SmoothL1Loss()

# %%
"""
train net
"""

def evaluate_acc(data_iter, ctx):
    data_iter.reset()
    box_metric = metric.MAE()
    outs, labels = None, None
    for i, batch in enumerate(data_iter):
        data = batch.data[0].as_in_context(ctx)
        label = batch.label[0].as_in_context(ctx)
        anchors, box_preds, cls_preds = net(data)
        box_offset, box_mask, cls_labels = MultiBoxTarget(anchors, label, cls_preds.transpose(axes=(0, 2, 1)),
                                                                  negative_mining_ratio=3.0)#, overlap_threshold=0.75)
        box_metric.update([box_offset], [box_preds * box_mask])
        
        cls_probs = nd.SoftmaxActivation(cls_preds.transpose((0, 2, 1)), mode='channel')
        out = MultiBoxDetection(cls_probs, box_preds, anchors, force_suppress=True, clip=False, nms_threshold=0.45)
        if outs is None:
            outs = out
            labels = label
        else:
            outs = nd.concat(outs, out, dim=0)
            labels = nd.concat(labels, label, dim=0)
    AP = evaluate_MAP(outs, labels)
    return AP, box_metric
        
info = {"train_ap": [], "valid_ap": [], "loss": []}
def train(net, start_epoch, end_epoch, trainer=None):
    if trainer is None:
        trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': 0.3, 'wd': 5e-4})
    box_metric = metric.MAE()
    
    for e in range(start_epoch, end_epoch):
        train_data.reset()
        box_metric.reset()
        tic = time.time()
        _loss = [0,0]
        if e == 100 or e == 150 or e==180:
            trainer.set_learning_rate(trainer.learning_rate * 0.5)
            
        outs, labels = None, None
        for i, batch in enumerate(train_data):
            data = batch.data[0].as_in_context(ctx)
            label = batch.label[0].as_in_context(ctx)
            with autograd.record():
                anchors, box_preds, cls_preds = net(data)
                box_offset, box_mask, cls_labels = MultiBoxTarget(anchors, label, cls_preds.transpose(axes=(0, 2, 1)),
                                                                  negative_mining_ratio=3.0)#, overlap_threshold=0.75)
                loss1 = cls_loss(cls_preds, cls_labels)
                loss2 = box_loss(box_preds, box_offset, box_mask)
                loss = loss1 + loss2
            loss.backward()
            trainer.step(data.shape[0])
            _loss[0] += nd.mean(loss1).asscalar()
            _loss[1] += nd.mean(loss2).asscalar()
            
            cls_probs = nd.SoftmaxActivation(cls_preds.transpose((0, 2, 1)), mode='channel')
            out = MultiBoxDetection(cls_probs, box_preds, anchors, force_suppress=True, clip=False, nms_threshold=0.45)
            if outs is None:
                outs = out
                labels = label
            else:
                outs = nd.concat(outs, out, dim=0)
                labels = nd.concat(labels, label, dim=0)
            
            box_metric.update([box_offset], [box_preds * box_mask])
        
        train_AP = evaluate_MAP(outs, labels)
        valid_AP, val_box_metric = evaluate_acc(valid_data, ctx)
        info["train_ap"].append(train_AP)
        info["valid_ap"].append(valid_AP)
        info["loss"].append(_loss)
        
        if (e+1) % 10 == 0:
            print "epoch: %d time: %.2f loss: %.4f, %.4f lr: %.4f" % (e, time.time() - tic,_loss[0], _loss[1], trainer.learning_rate),
            print "train mae: %.4f AP: %.4f" % (box_metric.get()[1], train_AP),
            print "valid mae: %.4f AP: %.4f" % (val_box_metric.get()[1], valid_AP)

net = SSD(2, sizes_list, ratios_list, ctx, verbose=False, prefix="ssd_")
# net.collect_params().initialize(ctx=ctx, force_reinit=True)
train(net, 0, 200)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-919463798fda> in <module>()
#      80 net = SSD(2, sizes_list, ratios_list, ctx, verbose=False, prefix="ssd_")
#      81 # net.collect_params().initialize(ctx=ctx, force_reinit=True)
# ---> 82 train(net, 0, 200)
#
# <ipython-input-8-919463798fda> in train(net, start_epoch, end_epoch, trainer)
#      45             label = batch.label[0].as_in_context(ctx)
#      46             with autograd.record():
# ---> 47                 anchors, box_preds, cls_preds = net(data)
#      48                 box_offset, box_mask, cls_labels = MultiBoxTarget(anchors, label, cls_preds.transpose(axes=(0, 2, 1)),
#      49                                                                   negative_mining_ratio=3.0)#, overlap_threshold=0.75)
#
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/block.pyc in __call__(self, *args)
#     288     def __call__(self, *args):
#     289         """Calls forward. Only accepts positional arguments."""
# --> 290         return self.forward(*args)
#     291
#     292     def forward(self, *args):
#
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/block.pyc in forward(self, x, *args)
#     472                         i._finish_deferred_init()
#     473                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
# --> 474                 return self.hybrid_forward(ndarray, x, *args, **params)
#     475
#     476         assert isinstance(x, Symbol), \
#
# <ipython-input-6-1179672bacbc> in hybrid_forward(self, F, x)
#      84
#      85             if i < 3:
# ---> 86                 x = self.downsamples[i](x)
#      87             elif i == 3:
#      88                 x = F.Pooling(x, global_pool=True, pool_type='max', kernel=(x.shape[2], x.shape[3]))
#
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/block.pyc in __call__(self, *args)
#     288     def __call__(self, *args):
#     289         """Calls forward. Only accepts positional arguments."""
# --> 290         return self.forward(*args)
#     291
#     292     def forward(self, *args):
#
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/block.pyc in forward(self, x, *args)
#     472                         i._finish_deferred_init()
#     473                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
# --> 474                 return self.hybrid_forward(ndarray, x, *args, **params)
#     475
#     476         assert isinstance(x, Symbol), \
#
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/nn/basic_layers.pyc in hybrid_forward(self, F, x)
#     103     def hybrid_forward(self, F, x):
#     104         for block in self._children:
# --> 105             x = block(x)
#     106         return x
#     107
#
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/block.pyc in __call__(self, *args)
#     288     def __call__(self, *args):
#     289         """Calls forward. Only accepts positional arguments."""
# --> 290         return self.forward(*args)
#     291
#     292     def forward(self, *args):
#
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/block.pyc in forward(self, x, *args)
#     472                         i._finish_deferred_init()
#     473                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
# --> 474                 return self.hybrid_forward(ndarray, x, *args, **params)
#     475
#     476         assert isinstance(x, Symbol), \
#
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/nn/conv_layers.pyc in hybrid_forward(self, F, x, weight, bias)
#     132             act = getattr(F, self._op_name)(x, weight, name='fwd', **self._kwargs)
#     133         else:
# --> 134             act = getattr(F, self._op_name)(x, weight, bias, name='fwd', **self._kwargs)
#     135         if self.act is not None:
#     136             act = self.act(act)
#
# /usr/local/lib/python2.7/dist-packages/mxnet/ndarray/register.pyc in Convolution(data, weight, bias, kernel, stride, dilate, pad, num_filter, num_group, workspace, no_bias, cudnn_tune, cudnn_off, layout, out, name, **kwargs)
#
# /usr/local/lib/python2.7/dist-packages/mxnet/_ctypes/ndarray.pyc in _imperative_invoke(handle, ndargs, keys, vals, out)
#      90         c_array(ctypes.c_char_p, [c_str(key) for key in keys]),
#      91         c_array(ctypes.c_char_p, [c_str(str(val)) for val in vals]),
# ---> 92         ctypes.byref(out_stypes)))
#      93
#      94     if original_output is not None:
#
# KeyboardInterrupt:

# %%
def plot(key):
    plt.plot(range(len(info[key])), info[key], label=key)


info["loss"] = np.array(info["loss"])
info["loss1"] = info["loss"][:, 0]
info["loss2"] = info["loss"][:, 1]

plt.figure(figsize=(12, 4))   # (w, h)
plt.subplot(121)
plot("train_ap")
plot("valid_ap")
plt.legend(loc="upper right")
plt.subplot(122)
plot("loss1")
plot("loss2")
plt.legend(loc="upper right")

# %%
mkdir_if_not_exist("../models")
net.save_params("../models/sdl_coin_vgg11bn_512x512_200_x.param")

# %% [markdown]
# ## 可视化测试结果

# %%
train_data.reset()
outs = None
labels = None
for i, batch in enumerate(train_data):
    data = batch.data[0].as_in_context(ctx)
    label = batch.label[0].as_in_context(ctx)
    anchors, box_preds, cls_preds = net(data)
    cls_probs = nd.SoftmaxActivation(cls_preds.transpose((0, 2, 1)), mode="channel")
    out = MultiBoxDetection(cls_probs, box_preds, anchors, force_suppress=True, clip=False, nms_threshold=0.45)
    if outs is None:
        outs = out
        labels = label
    else:
        outs = nd.concat(*[outs, out], dim=0)
        labels = nd.concat(*[labels, label], dim=0)

print outs.shape
print labels.shape
print evaluate_MAP(outs, labels)
draw_ROC(outs, labels, verbose=True)
# Out:
# (92L, 5444L, 6L)
# (92L, 14L, 5L)
# 0.801338392399

# %%
from utils.utils import find_best_score_th
score_th = find_best_score_th(outs.asnumpy(), labels.asnumpy())
print score_th
# Out:
# 0.989018

# %%
sizes_list = [[.2,.272], [.37,.447], [.54,.619],
                      [.71,.79], [.88,.961]]
ratios_list = [[1, 2, .5]]*5
net = SSD(2, sizes_list, ratios_list, ctx=ctx, verbose=False, prefix="ssd_")
net.initialize(ctx=ctx)
net.load_params("../models/sdl_coin_vgg11bn_512x512_200.param", ctx=ctx)
# Out:
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv0_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv0_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm0_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm0_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm0_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm0_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv1_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv1_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm1_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm1_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm1_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm1_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv2_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv2_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm2_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm2_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm2_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm2_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv3_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv3_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm3_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm3_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm3_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm3_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv4_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv4_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm4_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm4_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm4_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm4_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv5_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv5_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm5_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm5_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm5_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm5_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv6_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv6_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm6_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm6_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm6_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm6_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv7_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_conv7_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm7_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm7_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm7_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_vgg0_batchnorm7_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv0_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm0_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm0_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm0_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm0_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv1_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm1_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm1_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm1_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm1_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv2_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm2_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm2_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm2_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm2_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv3_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm3_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm3_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm3_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm3_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv4_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm4_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm4_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm4_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm4_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv5_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm5_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm5_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm5_running_mean is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_batchnorm5_running_var is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv6_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv8_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv10_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv12_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv14_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv7_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv9_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv11_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv13_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python2.7/dist-packages/mxnet/gluon/parameter.py:298: UserWarning: Parameter ssd_conv15_bias is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-93b9096639e0> in <module>()
#       6 net.load_params("../models/sdl_coin_vgg11bn_512x512_200.param", ctx=ctx)
#       7
# ----> 8 a, b = evaluate_acc(valid_data)
#       9 print a.get(), b.get()
#
# TypeError: evaluate_acc() takes exactly 2 arguments (1 given)

# %%
valid_data = image.ImageDetIter(
    batch_size=batch_size, 
    data_shape=data_shape,
    path_imgrec=sdl_root+"rec/sdl"+'_val.rec',
    shuffle=False,
    mean=True,
    #std=True
)

# %%
from utils.utils import show_det_results
from mxnet.contrib.ndarray import MultiBoxDetection

mpl.rcParams['figure.figsize'] = (6,6)
train_data.reset()
batch = train_data.next()
data = batch.data[0].as_in_context(ctx)
label = batch.label[0].as_in_context(ctx)
anchors, box_preds, cls_preds = net(data)
cls_probs = nd.SoftmaxActivation(cls_preds.transpose((0, 2, 1)), mode='channel')
out = MultiBoxDetection(cls_probs, box_preds, anchors, force_suppress=True, clip=False, nms_threshold=0.45)
box_offset, box_mask, cls_labels = MultiBoxTarget(anchors, label, 
                                                  cls_preds.transpose(axes=(0, 2, 1)), negative_mining_ratio=3)

imgs = (data.transpose((0, 2, 3, 1)).asnumpy() * std)+ rgb_mean
#plt.imshow(imgs[0] / 255)
show_det_results(imgs, out, threshold=0.5, show_text=False, MN=(2, 4))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-582d4c119795> in <module>()
# ----> 1 from utils.utils import show_det_results
#       2 from mxnet.contrib.ndarray import MultiBoxDetection
#       3
#       4 mpl.rcParams['figure.figsize'] = (6,6)
#       5 train_data.reset()
#
# ImportError: No module named utils.utils
